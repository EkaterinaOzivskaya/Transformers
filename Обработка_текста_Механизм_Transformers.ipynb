# %%
# Ваше решение
# Библиотека датасетов от tensorfolw
import tensorflow_datasets as tfds

# Библиотека для обучения НС
import tensorflow as tf

# Модуль отвечает за время и обработку временнЫх переменных
import time

# Библиотека для работы с массивами
import numpy as np

# Библиотека для отрисовки графиков и картинок
import matplotlib.pyplot as plt

# %%
examples, metadata = tfds.load('web_questions', # Имя датасета
                               with_info=True,                # Вывести информацию о датасете
                               as_supervised= False)            # Вывод будет иметь формат (input, label)

# Разделяем на обучающую и тестовую выборки
train_examples, val_examples = examples['train'], examples['test']
# Out:
# Downloading and preparing dataset 1.21 MiB (download: 1.21 MiB, generated: 983.88 KiB, total: 2.17 MiB) to /root/tensorflow_datasets/web_questions/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3778 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/web_questions/1.0.0.incomplete3KOFTS/web_questions-train.tfrecord*...:   0…
# Generating test examples...:   0%|          | 0/2032 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/web_questions/1.0.0.incomplete3KOFTS/web_questions-test.tfrecord*...:   0%…
# Dataset web_questions downloaded and prepared to /root/tensorflow_datasets/web_questions/1.0.0. Subsequent calls will reuse this data.

# %%
train_examples
# Out:
# <_PrefetchDataset element_spec={'answers': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'question': TensorSpec(shape=(), dtype=tf.string, name=None), 'url': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# Выведем первые 5 пар предложений
for ques in train_examples.take(5):
  print(ques)
  #print('Английский:   ', ans.numpy())
  print()
# Out:
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Joe Flacco'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'who is the ravens quarterback 2012?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/baltimore_ravens'>}
#
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Whig Party'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what political party was henry clay?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/henry_clay'>}
#
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'UTC+07:00'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'where to stay in thailand koh samui?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/ko_samui'>}
#
# {'answers': <tf.Tensor: shape=(10,), dtype=string, numpy=
# array([b'Bahrain', b'Afghanistan', b'Bangladesh', b'Bhutan', b'Brunei',
#        b'Indonesia', b'India', b'Cambodia', b'China', b'Iraq'],
#       dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what countries are included in the continent of asia?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/asia'>}
#
# {'answers': <tf.Tensor: shape=(10,), dtype=string, numpy=
# array([b'Murder Was the Case', b'Above the Rim', b'Bullet',
#        b'Gang Related', b'Watch Juice',
#        b'Tupac: Live at the House of Blues', b'Nothing but Trouble',
#        b'Juice', b'Poetic Justice', b"Gridlock'd"], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what movies does tupac act in?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/tupac_shakur'>}

# %%
# Токенайзер для question, с размером словаря 2**13
tokenizer_en = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (str(all['question'].numpy(), encoding = 'UTF-8') for all in train_examples), target_vocab_size=2**13)

# %%
# Размер словаря
tokenizer_en.vocab_size
# Out:
# 4513

# %%
dir(tokenizer_en)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_from_token_counts',
#  '_byte_encode',
#  '_cache_size',
#  '_filename',
#  '_id_to_subword',
#  '_init_from_list',
#  '_max_subword_len',
#  '_read_lines_from_file',
#  '_subword_to_id',
#  '_subwords',
#  '_token_to_ids',
#  '_token_to_ids_cache',
#  '_token_to_subwords',
#  '_tokenizer',
#  '_write_lines_to_file',
#  'build_from_corpus',
#  'decode',
#  'encode',
#  'load_from_file',
#  'save_to_file',
#  'subwords',
#  'vocab_size']

# %%
# QUE и ANS это вопросы и ответы
def encode(que, ans):

  # Добавление токенов start и end в текст вопроса
  QUE = [tokenizer_en.vocab_size] + tokenizer_en.encode(
      str(que.numpy(), encoding='UTF-8')) + [tokenizer_en.vocab_size+1]

  # Добавление токенов start и end в текст ответа
  ANS = [tokenizer_en.vocab_size] + tokenizer_en.encode(
      str(ans.numpy()[0], encoding='UTF-8')) + [tokenizer_en.vocab_size+1]

  return QUE, ANS

# %%
# Обертка над предыдущей функцией encode()
def tf_encode(full):
  result_q, result_a = tf.py_function(encode,               # Функция
                                        [full['question'], # Аргументы
                                          full['answers']],            # Аргументы
                                        [tf.int64, tf.int64]) # Типы данных
  result_q.set_shape([None])
  result_a.set_shape([None])

  return result_q, result_a

# %%
# Размер буфера в памяти при подготовке датасета
BUFFER_SIZE = 20000

# Размер батча
BATCH_SIZE = 64

# Максимальная длина фраз
MAX_LENGTH = 40

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):

  return tf.logical_and(tf.size(x) <= max_length, # Маска для значений x
                        tf.size(y) <= max_length) # Маска для значений y

# %%
# Прогоняем обучающие тексты через токенайзер
# Благодаря .map мы применим функцию tf_encode к каждому примеру выборки
train_dataset = train_examples.map(tf_encode)

# Фильтруем по максимальной длинне
train_dataset = train_dataset.filter(filter_max_length)

# Кэшируем данные в память для ускорения работы
train_dataset = train_dataset.cache()

# Делим на батчи и перемешиваем
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE)

# # .prefetch используется для разделения времени, когда данные производятся,
# от времени, когда данные потребляются. Это ускоряет обучение сети
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

# Прогоняем проверочные тексты через токенайзер
val_dataset = val_examples.map(tf_encode)

# Фильтруем по максимальной длинне
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
# Возьмем первый батч датасета
questions_batch, answers_batch = next(iter(val_dataset))

# Посмотрим что внутри
questions_batch, answers_batch
# Out:
# (<tf.Tensor: shape=(64, 24), dtype=int64, numpy=
#  array([[4513,    1,   40, ...,    0,    0,    0],
#         [4513,    5,  311, ...,    0,    0,    0],
#         [4513,    5,  255, ...,    0,    0,    0],
#         ...,
#         [4513,    5,    3, ...,    0,    0,    0],
#         [4513,    1,    3, ...,    0,    0,    0],
#         [4513,    1,   37, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 29), dtype=int64, numpy=
#  array([[4513, 4229, 4335, ...,    0,    0,    0],
#         [4513, 4340, 4354, ...,    0,    0,    0],
#         [4513, 4322, 4372, ...,    0,    0,    0],
#         ...,
#         [4513, 4341, 4368, ...,    0,    0,    0],
#         [4513, 4323,  303, ...,    0,    0,    0],
#         [4513, 4322, 4367, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):

  # По формуле рассчитаем аргументы позиционного кодирования
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):

  # Получаем аргументы
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

  # Чётные индексы будут принимать значение от sin
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  # Нечётные индексы будут принимать значение от cos
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  # Добавляем ещё одну размерность
  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# Зададим значения 50, 512
pos_encoding = positional_encoding(50, 512)
print(pos_encoding.shape)

# Выведем значения поз. кодирования в виде heatmap
plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 50, 512)

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model = 512, num_heads = 8, causal = False, dropout = 0.0):

    super(MultiHeadAttention, self).__init__()
    assert d_model % num_heads == 0
    depth = d_model // num_heads

    self.w_query = tf.keras.layers.Dense(d_model)
    self.split_reshape_query = tf.keras.layers.Reshape((-1, num_heads, depth))
    self.split_permute_query = tf.keras.layers.Permute((2, 1, 3))


    self.w_value = tf.keras.layers.Dense(d_model)
    self.split_reshape_value = tf.keras.layers.Reshape((-1, num_heads, depth))
    self.split_permute_value = tf.keras.layers.Permute((2, 1, 3))


    self.w_key = tf.keras.layers.Dense(d_model)
    self.split_reshape_key = tf.keras.layers.Reshape((-1, num_heads, depth))
    self.split_permute_key = tf.keras.layers.Permute((2, 1, 3))


    self.attention = tf.keras.layers.Attention(causal=causal, dropout = dropout)
    self.join_permute_attention = tf.keras.layers.Permute((2, 1, 3))
    self.join_reshape_attention = tf.keras.layers.Reshape((-1, d_model))

    self.dense = tf.keras.layers.Dense(d_model)
  def call(self, inputs, mask=None, training=None): # Основная рабочая функция

    q = inputs[0]                           # Вытащим входной вектор Query
    v = inputs[1]                           # Вытащим входной вектор Value
    k = inputs[2] if len(inputs) > 2 else v # Вытащим входной вектор Key

    query = self.w_query(q)                   # Прогоним через dense
    query = self.split_reshape_query(query)   # Решейпим
    query = self.split_permute_query(query)   # Переставляем размерность

    value = self.w_value(v)                 # Прогоним через dense
    value = self.split_reshape_value(value) # Решейпим
    value = self.split_permute_value(value) # Переставляем размерность

    key = self.w_key(k)               # Прогоним через dense
    key = self.split_reshape_key(key) # Решейпим
    key = self.split_permute_key(key) # Переставляем размерность

    if mask is not None: # Применим маску если есть

      if mask[0] is not None:
        mask[0] = tf.keras.layers.Reshape((-1,1))(mask[0])     # Слой для решейпа
        mask[0] = tf.keras.layers.Permute((2,1))(mask[0])      # Слой для перестановки размерностей

      if mask[1] is not None:
        mask[1] = tf.keras.layers.Reshape((-1,1))(mask[1])     # Слой для решейпа
        mask[1] = tf.keras.layers.Permute((2,1))(mask[1])      # Слой для перестановки размерностей

    attention = self.attention([query, value, key], mask=mask) # Вычисляем вектор внимания
    attention = self.join_permute_attention(attention)         # Обратно перемешиваем размерности
    attention = self.join_reshape_attention(attention)

    x = self.dense(attention) # Выходной dense

    return x

# %%
class EncoderLayer(tf.keras.layers.Layer):

  def __init__(self,
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout

    super(EncoderLayer, self).__init__()

    self.multi_head_attention = MultiHeadAttention(d_model, num_heads)   # Определим слой  MultiHeadAttention
    self.dropout_attention = tf.keras.layers.Dropout(dropout)            # Добавим дропаут
    self.add_attention = tf.keras.layers.Add()                           # Слой для получения resudial связи
    self.layer_norm_attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')               # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                              # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                     # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                    # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

  def call(self, inputs, mask=None, training=None):

    # Входной вектор input размножим до 3 - это query, value, key и отдадим attenton, с маской если есть
    attention = self.multi_head_attention([inputs,inputs,inputs], mask = [mask,mask])

    # Уменьшим переобучение дроаутом
    attention = self.dropout_attention(attention, training = training)

    # Сделаем resudial связь - добавим входной вектор
    x = self.add_attention([inputs , attention])

    # Далее нормализация в масштабах уровня
    x = self.layer_norm_attention(x)
    # x = inputs

    # Добавим Feed Forward

    # Проходим 1й dense с активашкой relu
    dense = self.dense1(x)

    # Второй dense без активашки т.е. с линейной активационной функцией
    dense = self.dense2(dense)

    # Добавляем дропаут
    dense = self.dropout_dense(dense, training = training)

    # Еще одна resudial связь
    x = self.add_dense([x , dense])

    # Нормализация в масштабах уровня
    x = self.layer_norm_dense(x)

    return x

# %%
class DecoderLayer(tf.keras.layers.Layer):

  def __init__(self,
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout

    super(DecoderLayer, self).__init__()

    self.multi_head_attention1 =  MultiHeadAttention(d_model, num_heads, causal = True) # Определим слой  MultiHeadAttention
    self.dropout_attention1 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention1 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации

    self.multi_head_attention2 =  MultiHeadAttention(d_model, num_heads)                # Определим слой  MultiHeadAttention
    self.dropout_attention2 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention2 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации


    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')                         # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                                        # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                               # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                              # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)            # Слой нормализации

  def call(self, inputs, mask=None, training=None):

    # Подадим на multi-head attention  Query, Key, Value вектора - здесь это один и тотже вектор
    attention = self.multi_head_attention1([inputs[0],inputs[0],inputs[0]], mask = [mask[0],mask[0]])

    # Пробежим дропаут
    attention = self.dropout_attention1(attention, training = training)

    # Пробросим Resudial-связь
    x = self.add_attention1([inputs[0] , attention])

    # Выполним нормализацию
    x = self.layer_norm_attention1(x)

    # Второй multi-head attention. Подаем выход предыдущих слоев x и выход от энкодера, маску (если есть)
    attention = self.multi_head_attention2([x, inputs[1],inputs[1]], mask = [mask[0],mask[1]])

    # Прогоняем через дропаут
    attention = self.dropout_attention2(attention, training = training)

    # Пробросим Resudial-связь
    x = self.add_attention1([x , attention])

    # Выполним нормализацию
    x = self.layer_norm_attention1(x)

    ## Feed Forward

    # 1 dense + relu
    dense = self.dense1(x)

    # 2 dense +linear
    dense = self.dense2(dense)

    # Прогоняем через дропаут
    dense = self.dropout_dense(dense, training = training)

    # Пробросим Resudial-связь
    x = self.add_dense([x , dense])

    # Выполним нормализацию
    x = self.layer_norm_dense(x)

    return x

# %%
class Encoder(tf.keras.layers.Layer):

  def __init__(self,
               input_vocab_size,                  # Размер словаря
               num_layers = 4,                    # Количество слоев энкодера
               d_model = 512,                     # Максимальная длина предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout

    super(Encoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, # Пропишем слой Embedding
                                               d_model,
                                               mask_zero=True)

    self.pos = positional_encoding(maximum_position_encoding,    # Функция позиционного кодирования
                                   d_model)

    self.encoder_layers = [ EncoderLayer(d_model = d_model,      # Список Nx слоев кодера
                                         num_heads = num_heads,
                                         dff = dff,
                                         dropout = dropout) for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(dropout)              # Просто дропаут

  def call(self, inputs, mask=None, training=None):

    # Входной эмбеддинг
    x = self.embedding(inputs)

    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos[: , :tf.shape(x)[1], :]

    # Прогоняем через дроаут
    x = self.dropout(x, training=training)

    # Входной слой embedding+ Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs)

    # Прогоним через Nx слоев кодера
    for encoder_layer in self.encoder_layers:
      x = encoder_layer(x, mask = embedding_mask)

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs)

# %%
class Decoder(tf.keras.layers.Layer):

  def __init__(self,
               target_vocab_size,                 # Размер словаря выходных данных
               num_layers = 4,                    # Количество слоев декодера
               d_model = 512,                     # Максимальный размер предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout

    super(Decoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, # Пропишем слой Embedding
                                               d_model,
                                               mask_zero=True)

    self.pos = positional_encoding(maximum_position_encoding,     # Функция позиционного кодирования
                                   d_model)

    self.decoder_layers = [ DecoderLayer(d_model = d_model,
                                         num_heads = num_heads,
                                         dff = dff,
                                         dropout = dropout)  for _ in range(num_layers)] # Список Nx слоев декодера

    self.dropout = tf.keras.layers.Dropout(dropout)               # Слой дропаут

  def call(self, inputs, mask=None, training=None):

    # Выполним переход в эмбеддинг
    x = self.embedding(inputs[0])

    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos[: , :tf.shape(x)[1], :]

    # Просто dropout
    x = self.dropout(x, training=training)

    # Входной слой embedding + Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs[0])

    # Прогоним через Nx слоев декодера
    for decoder_layer in self.decoder_layers:
      x = decoder_layer([x,inputs[1]], mask = [embedding_mask, mask])

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs[0])

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8

dropout_rate = 0.1

input_vocab_size = tokenizer_en.vocab_size + 2     # Индекс входного тега
target_vocab_size = tokenizer_en.vocab_size + 3    # Индекс выходного тега


input  = tf.keras.layers.Input(shape=(None,)) # Входной слой для переводимой фразы
target = tf.keras.layers.Input(shape=(None,)) # Вход для перевода

encoder = Encoder(input_vocab_size,           # Создаем энкодер
                  num_layers = num_layers,
                  d_model = d_model,
                  num_heads = num_heads,
                  dff = dff,
                  dropout = dropout_rate)

decoder = Decoder(target_vocab_size,          # Создаем декодер
                  num_layers = num_layers,
                  d_model = d_model,
                  num_heads = num_heads,
                  dff = dff,
                  dropout = dropout_rate)

# Собираем модель
x = encoder(input)
x = decoder([target, x] , mask = encoder.compute_mask(input))
x = tf.keras.layers.Dense(target_vocab_size)(x)

# Формируем модель, выводим саммери
model = tf.keras.models.Model(inputs=[input, target], outputs=x)
model.summary()
# Out:
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# WARNING:absl:`causal` argument is deprecated. Please use `use_causal_mask` in call() method to specify causal masking.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, None)]       0           []
#
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  encoder_1 (Encoder)            (None, None, 128)    1371008     ['input_3[0][0]']
#
#  tf.math.not_equal (TFOpLambda)  (None, None)        0           ['input_3[0][0]']
#
#  decoder (Decoder)              (None, None, 128)    1635328     ['input_4[0][0]',
#                                                                   'encoder_1[0][0]',
#                                                                   'tf.math.not_equal[0][0]']
#
#  dense_67 (Dense)               (None, None, 4516)   582564      ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 3,588,900
# Trainable params: 3,588,900
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
# Оптимайзер
optimizer = tf.keras.optimizers.Adam(CustomSchedule(d_model),
                                     beta_1=0.9,
                                     beta_2=0.98,
                                     epsilon=1e-9)
# Функция потерь
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# Мы рассчитываем потери, используя предопределенную целевую функцию,
# а затем дополняем ее маской.

def masked_loss(y_true, y_pred):

  # Считаем маску
  mask = tf.math.logical_not(tf.math.equal(y_true, 0))
  _loss = loss(y_true, y_pred)

  mask = tf.cast(mask, dtype=_loss.dtype)

  # Накинем маску на потери
  _loss *= mask

  return tf.reduce_sum(_loss)/tf.reduce_sum(mask)

metrics = [loss, masked_loss, tf.keras.metrics.SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss = loss, metrics = metrics) # masked_

# %%
# Количество батчей для обучения
num_batches = 0
for (batch, (_,_)) in enumerate(train_dataset):
  num_batches = batch
print(num_batches)

# Количество батчей для проверки
val_batches = 0
for (batch, (_,_)) in enumerate(val_dataset):
  val_batches = batch
print(val_batches)
# Out:
# 58
# 31

# %%
# Создадим генератор данных для обучения
def generator(data_set):

  while True:
    for q_batch, a_batch in data_set:
      yield ( [q_batch , a_batch[:, :-1] ] , a_batch[:, 1:] )

# При помощи генератора запускаем обучение
history = model.fit(x = generator(train_dataset),              # Данные для обучения
                    validation_data = generator(val_dataset),  # Данные для проверки
                    epochs=200,                                # Количество эпох
                    steps_per_epoch = num_batches,             # Количество батчей
                    validation_steps = val_batches)            # Батчи на проверку
# Out:
# Epoch 1/200
# 58/58 [==============================] - 84s 606ms/step - loss: 3.4596 - sparse_categorical_crossentropy: 8.3001 - masked_loss: 8.3389 - sparse_categorical_accuracy: 0.0205 - val_loss: 3.3865 - val_sparse_categorical_crossentropy: 8.0770 - val_masked_loss: 8.1361 - val_sparse_categorical_accuracy: 0.0813
# Epoch 2/200
# 58/58 [==============================] - 12s 197ms/step - loss: 3.3116 - sparse_categorical_crossentropy: 7.8893 - masked_loss: 7.9503 - sparse_categorical_accuracy: 0.0738 - val_loss: 3.1919 - val_sparse_categorical_crossentropy: 7.6128 - val_masked_loss: 7.6846 - val_sparse_categorical_accuracy: 0.0742
# Epoch 3/200
# 58/58 [==============================] - 10s 180ms/step - loss: 3.0504 - sparse_categorical_crossentropy: 7.3489 - masked_loss: 7.4217 - sparse_categorical_accuracy: 0.0764 - val_loss: 2.9208 - val_sparse_categorical_crossentropy: 6.9664 - val_masked_loss: 7.0466 - val_sparse_categorical_accuracy: 0.0742
# Epoch 4/200
# 58/58 [==============================] - 8s 133ms/step - loss: 2.7882 - sparse_categorical_crossentropy: 6.5882 - masked_loss: 6.6743 - sparse_categorical_accuracy: 0.0786 - val_loss: 2.5506 - val_sparse_categorical_crossentropy: 6.0835 - val_masked_loss: 6.1967 - val_sparse_categorical_accuracy: 0.0827
# Epoch 5/200
# 58/58 [==============================] - 11s 187ms/step - loss: 2.3983 - sparse_categorical_crossentropy: 5.6580 - masked_loss: 5.7903 - sparse_categorical_accuracy: 0.1062 - val_loss: 2.1709 - val_sparse_categorical_crossentropy: 5.1779 - val_masked_loss: 5.3292 - val_sparse_categorical_accuracy: 0.1348
# Epoch 6/200
# 58/58 [==============================] - 8s 141ms/step - loss: 2.0418 - sparse_categorical_crossentropy: 4.8499 - masked_loss: 5.0054 - sparse_categorical_accuracy: 0.1528 - val_loss: 1.8906 - val_sparse_categorical_crossentropy: 4.5092 - val_masked_loss: 4.6842 - val_sparse_categorical_accuracy: 0.1785
# Epoch 7/200
# 58/58 [==============================] - 9s 165ms/step - loss: 1.8507 - sparse_categorical_crossentropy: 4.3116 - masked_loss: 4.4991 - sparse_categorical_accuracy: 0.1811 - val_loss: 1.7294 - val_sparse_categorical_crossentropy: 4.1248 - val_masked_loss: 4.3393 - val_sparse_categorical_accuracy: 0.1868
# Epoch 8/200
# 58/58 [==============================] - 7s 119ms/step - loss: 1.6836 - sparse_categorical_crossentropy: 4.0024 - masked_loss: 4.2308 - sparse_categorical_accuracy: 0.1928 - val_loss: 1.6216 - val_sparse_categorical_crossentropy: 3.8677 - val_masked_loss: 4.1191 - val_sparse_categorical_accuracy: 0.2099
# Epoch 9/200
# 58/58 [==============================] - 8s 132ms/step - loss: 1.5879 - sparse_categorical_crossentropy: 3.7565 - masked_loss: 4.0137 - sparse_categorical_accuracy: 0.2176 - val_loss: 1.5080 - val_sparse_categorical_crossentropy: 3.5967 - val_masked_loss: 3.8600 - val_sparse_categorical_accuracy: 0.2402
# Epoch 10/200
# 58/58 [==============================] - 9s 155ms/step - loss: 1.4629 - sparse_categorical_crossentropy: 3.5123 - masked_loss: 3.7760 - sparse_categorical_accuracy: 0.2345 - val_loss: 1.4217 - val_sparse_categorical_crossentropy: 3.3909 - val_masked_loss: 3.6520 - val_sparse_categorical_accuracy: 0.2431
# Epoch 11/200
# 58/58 [==============================] - 8s 139ms/step - loss: 1.4016 - sparse_categorical_crossentropy: 3.3465 - masked_loss: 3.6065 - sparse_categorical_accuracy: 0.2459 - val_loss: 1.3615 - val_sparse_categorical_crossentropy: 3.2473 - val_masked_loss: 3.5025 - val_sparse_categorical_accuracy: 0.2675
# Epoch 12/200
# 58/58 [==============================] - 8s 142ms/step - loss: 1.3490 - sparse_categorical_crossentropy: 3.2002 - masked_loss: 3.4565 - sparse_categorical_accuracy: 0.2616 - val_loss: 1.3150 - val_sparse_categorical_crossentropy: 3.1364 - val_masked_loss: 3.3851 - val_sparse_categorical_accuracy: 0.2778
# Epoch 13/200
# 58/58 [==============================] - 9s 158ms/step - loss: 1.3264 - sparse_categorical_crossentropy: 3.1067 - masked_loss: 3.3523 - sparse_categorical_accuracy: 0.2736 - val_loss: 1.2790 - val_sparse_categorical_crossentropy: 3.0505 - val_masked_loss: 3.2935 - val_sparse_categorical_accuracy: 0.2847
# Epoch 14/200
# 58/58 [==============================] - 9s 160ms/step - loss: 1.2518 - sparse_categorical_crossentropy: 3.0096 - masked_loss: 3.2518 - sparse_categorical_accuracy: 0.2917 - val_loss: 1.2370 - val_sparse_categorical_crossentropy: 2.9504 - val_masked_loss: 3.1860 - val_sparse_categorical_accuracy: 0.3080
# Epoch 15/200
# 58/58 [==============================] - 6s 109ms/step - loss: 1.2076 - sparse_categorical_crossentropy: 2.9212 - masked_loss: 3.1529 - sparse_categorical_accuracy: 0.3076 - val_loss: 1.2126 - val_sparse_categorical_crossentropy: 2.8921 - val_masked_loss: 3.1233 - val_sparse_categorical_accuracy: 0.3207
# Epoch 16/200
# 58/58 [==============================] - 7s 124ms/step - loss: 1.1820 - sparse_categorical_crossentropy: 2.8251 - masked_loss: 3.0527 - sparse_categorical_accuracy: 0.3262 - val_loss: 1.1850 - val_sparse_categorical_crossentropy: 2.8262 - val_masked_loss: 3.0523 - val_sparse_categorical_accuracy: 0.3348
# Epoch 17/200
# 58/58 [==============================] - 9s 162ms/step - loss: 1.1600 - sparse_categorical_crossentropy: 2.7514 - masked_loss: 2.9739 - sparse_categorical_accuracy: 0.3422 - val_loss: 1.1551 - val_sparse_categorical_crossentropy: 2.7551 - val_masked_loss: 2.9755 - val_sparse_categorical_accuracy: 0.3459
# Epoch 18/200
# 58/58 [==============================] - 7s 116ms/step - loss: 1.1135 - sparse_categorical_crossentropy: 2.6626 - masked_loss: 2.8751 - sparse_categorical_accuracy: 0.3572 - val_loss: 1.1450 - val_sparse_categorical_crossentropy: 2.7310 - val_masked_loss: 2.9496 - val_sparse_categorical_accuracy: 0.3491
# Epoch 19/200
# 58/58 [==============================] - 7s 123ms/step - loss: 1.1042 - sparse_categorical_crossentropy: 2.6081 - masked_loss: 2.8194 - sparse_categorical_accuracy: 0.3672 - val_loss: 1.1196 - val_sparse_categorical_crossentropy: 2.6703 - val_masked_loss: 2.8841 - val_sparse_categorical_accuracy: 0.3622
# Epoch 20/200
# 58/58 [==============================] - 9s 154ms/step - loss: 1.0729 - sparse_categorical_crossentropy: 2.5196 - masked_loss: 2.7216 - sparse_categorical_accuracy: 0.3860 - val_loss: 1.1118 - val_sparse_categorical_crossentropy: 2.6517 - val_masked_loss: 2.8641 - val_sparse_categorical_accuracy: 0.3694
# Epoch 21/200
# 58/58 [==============================] - 9s 164ms/step - loss: 1.0037 - sparse_categorical_crossentropy: 2.4534 - masked_loss: 2.6512 - sparse_categorical_accuracy: 0.3976 - val_loss: 1.1091 - val_sparse_categorical_crossentropy: 2.6454 - val_masked_loss: 2.8572 - val_sparse_categorical_accuracy: 0.3745
# Epoch 22/200
# 58/58 [==============================] - 8s 134ms/step - loss: 1.0348 - sparse_categorical_crossentropy: 2.4011 - masked_loss: 2.5929 - sparse_categorical_accuracy: 0.4068 - val_loss: 1.0918 - val_sparse_categorical_crossentropy: 2.6040 - val_masked_loss: 2.8126 - val_sparse_categorical_accuracy: 0.3839
# Epoch 23/200
# 58/58 [==============================] - 6s 109ms/step - loss: 0.9614 - sparse_categorical_crossentropy: 2.3243 - masked_loss: 2.5135 - sparse_categorical_accuracy: 0.4248 - val_loss: 1.0822 - val_sparse_categorical_crossentropy: 2.5811 - val_masked_loss: 2.7878 - val_sparse_categorical_accuracy: 0.3894
# Epoch 24/200
# 58/58 [==============================] - 15s 267ms/step - loss: 0.9338 - sparse_categorical_crossentropy: 2.2614 - masked_loss: 2.4429 - sparse_categorical_accuracy: 0.4369 - val_loss: 1.0824 - val_sparse_categorical_crossentropy: 2.5817 - val_masked_loss: 2.7885 - val_sparse_categorical_accuracy: 0.3913
# Epoch 25/200
# 58/58 [==============================] - 9s 158ms/step - loss: 0.9117 - sparse_categorical_crossentropy: 2.1738 - masked_loss: 2.3488 - sparse_categorical_accuracy: 0.4548 - val_loss: 1.0670 - val_sparse_categorical_crossentropy: 2.5448 - val_masked_loss: 2.7487 - val_sparse_categorical_accuracy: 0.4032
# Epoch 26/200
# 58/58 [==============================] - 8s 134ms/step - loss: 0.9074 - sparse_categorical_crossentropy: 2.1277 - masked_loss: 2.2979 - sparse_categorical_accuracy: 0.4645 - val_loss: 1.0557 - val_sparse_categorical_crossentropy: 2.5179 - val_masked_loss: 2.7195 - val_sparse_categorical_accuracy: 0.4087
# Epoch 27/200
# 58/58 [==============================] - 7s 119ms/step - loss: 0.8679 - sparse_categorical_crossentropy: 2.0848 - masked_loss: 2.2527 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.0711 - val_sparse_categorical_crossentropy: 2.5547 - val_masked_loss: 2.7593 - val_sparse_categorical_accuracy: 0.4102
# Epoch 28/200
# 58/58 [==============================] - 7s 116ms/step - loss: 0.8608 - sparse_categorical_crossentropy: 2.0013 - masked_loss: 2.1632 - sparse_categorical_accuracy: 0.4906 - val_loss: 1.0850 - val_sparse_categorical_crossentropy: 2.5878 - val_masked_loss: 2.7950 - val_sparse_categorical_accuracy: 0.4075
# Epoch 29/200
# 58/58 [==============================] - 7s 122ms/step - loss: 0.8363 - sparse_categorical_crossentropy: 1.9804 - masked_loss: 2.1388 - sparse_categorical_accuracy: 0.4912 - val_loss: 1.0677 - val_sparse_categorical_crossentropy: 2.5465 - val_masked_loss: 2.7505 - val_sparse_categorical_accuracy: 0.4161
# Epoch 30/200
# 58/58 [==============================] - 7s 116ms/step - loss: 0.7982 - sparse_categorical_crossentropy: 1.8744 - masked_loss: 2.0263 - sparse_categorical_accuracy: 0.5184 - val_loss: 1.0679 - val_sparse_categorical_crossentropy: 2.5470 - val_masked_loss: 2.7510 - val_sparse_categorical_accuracy: 0.4160
# Epoch 31/200
# 58/58 [==============================] - 12s 212ms/step - loss: 0.7803 - sparse_categorical_crossentropy: 1.8569 - masked_loss: 2.0060 - sparse_categorical_accuracy: 0.5205 - val_loss: 1.0663 - val_sparse_categorical_crossentropy: 2.5432 - val_masked_loss: 2.7469 - val_sparse_categorical_accuracy: 0.4276
# Epoch 32/200
# 58/58 [==============================] - 8s 131ms/step - loss: 0.7542 - sparse_categorical_crossentropy: 1.7872 - masked_loss: 1.9300 - sparse_categorical_accuracy: 0.5357 - val_loss: 1.0690 - val_sparse_categorical_crossentropy: 2.5497 - val_masked_loss: 2.7540 - val_sparse_categorical_accuracy: 0.4258
# Epoch 33/200
# 58/58 [==============================] - 6s 112ms/step - loss: 0.7526 - sparse_categorical_crossentropy: 1.7487 - masked_loss: 1.8893 - sparse_categorical_accuracy: 0.5428 - val_loss: 1.0652 - val_sparse_categorical_crossentropy: 2.5405 - val_masked_loss: 2.7440 - val_sparse_categorical_accuracy: 0.4302
# Epoch 34/200
# 58/58 [==============================] - 7s 120ms/step - loss: 0.7046 - sparse_categorical_crossentropy: 1.6652 - masked_loss: 1.7984 - sparse_categorical_accuracy: 0.5620 - val_loss: 1.0623 - val_sparse_categorical_crossentropy: 2.5336 - val_masked_loss: 2.7366 - val_sparse_categorical_accuracy: 0.4378
# Epoch 35/200
# 58/58 [==============================] - 7s 121ms/step - loss: 0.6893 - sparse_categorical_crossentropy: 1.6343 - masked_loss: 1.7656 - sparse_categorical_accuracy: 0.5689 - val_loss: 1.0660 - val_sparse_categorical_crossentropy: 2.5425 - val_masked_loss: 2.7462 - val_sparse_categorical_accuracy: 0.4427
# Epoch 36/200
# 58/58 [==============================] - 15s 257ms/step - loss: 0.6592 - sparse_categorical_crossentropy: 1.5903 - masked_loss: 1.7201 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.0725 - val_sparse_categorical_crossentropy: 2.5580 - val_masked_loss: 2.7628 - val_sparse_categorical_accuracy: 0.4432
# Epoch 37/200
# 58/58 [==============================] - 9s 154ms/step - loss: 0.6454 - sparse_categorical_crossentropy: 1.5475 - masked_loss: 1.6713 - sparse_categorical_accuracy: 0.5844 - val_loss: 1.1016 - val_sparse_categorical_crossentropy: 2.6274 - val_masked_loss: 2.8378 - val_sparse_categorical_accuracy: 0.4410
# Epoch 38/200
# 58/58 [==============================] - 9s 156ms/step - loss: 0.6143 - sparse_categorical_crossentropy: 1.4975 - masked_loss: 1.6183 - sparse_categorical_accuracy: 0.5970 - val_loss: 1.0992 - val_sparse_categorical_crossentropy: 2.6216 - val_masked_loss: 2.8316 - val_sparse_categorical_accuracy: 0.4402
# Epoch 39/200
# 58/58 [==============================] - 7s 123ms/step - loss: 0.6078 - sparse_categorical_crossentropy: 1.4457 - masked_loss: 1.5620 - sparse_categorical_accuracy: 0.6095 - val_loss: 1.1054 - val_sparse_categorical_crossentropy: 2.6364 - val_masked_loss: 2.8475 - val_sparse_categorical_accuracy: 0.4449
# Epoch 40/200
# 58/58 [==============================] - 9s 152ms/step - loss: 0.5922 - sparse_categorical_crossentropy: 1.4082 - masked_loss: 1.5206 - sparse_categorical_accuracy: 0.6129 - val_loss: 1.1120 - val_sparse_categorical_crossentropy: 2.6523 - val_masked_loss: 2.8646 - val_sparse_categorical_accuracy: 0.4527
# Epoch 41/200
# 58/58 [==============================] - 9s 159ms/step - loss: 0.5672 - sparse_categorical_crossentropy: 1.3509 - masked_loss: 1.4599 - sparse_categorical_accuracy: 0.6286 - val_loss: 1.1207 - val_sparse_categorical_crossentropy: 2.6730 - val_masked_loss: 2.8870 - val_sparse_categorical_accuracy: 0.4487
# Epoch 42/200
# 58/58 [==============================] - 7s 114ms/step - loss: 0.5508 - sparse_categorical_crossentropy: 1.3121 - masked_loss: 1.4184 - sparse_categorical_accuracy: 0.6366 - val_loss: 1.1367 - val_sparse_categorical_crossentropy: 2.7111 - val_masked_loss: 2.9282 - val_sparse_categorical_accuracy: 0.4566
# Epoch 43/200
# Epoch 53/200
# 58/58 [==============================] - 7s 124ms/step - loss: 0.3920 - sparse_categorical_crossentropy: 0.9473 - masked_loss: 1.0231 - sparse_categorical_accuracy: 0.7235 - val_loss: 1.2478 - val_sparse_categorical_crossentropy: 2.9760 - val_masked_loss: 3.2144 - val_sparse_categorical_accuracy: 0.4595
# Epoch 54/200
# 58/58 [==============================] - 9s 158ms/step - loss: 0.3871 - sparse_categorical_crossentropy: 0.9089 - masked_loss: 0.9819 - sparse_categorical_accuracy: 0.7323 - val_loss: 1.2623 - val_sparse_categorical_crossentropy: 3.0107 - val_masked_loss: 3.2519 - val_sparse_categorical_accuracy: 0.4595
# Epoch 55/200
# 58/58 [==============================] - 9s 155ms/step - loss: 0.3790 - sparse_categorical_crossentropy: 0.9038 - masked_loss: 0.9764 - sparse_categorical_accuracy: 0.7328 - val_loss: 1.2668 - val_sparse_categorical_crossentropy: 3.0215 - val_masked_loss: 3.2635 - val_sparse_categorical_accuracy: 0.4595
# Epoch 56/200
# 58/58 [==============================] - 7s 122ms/step - loss: 0.3719 - sparse_categorical_crossentropy: 0.8808 - masked_loss: 0.9517 - sparse_categorical_accuracy: 0.7409 - val_loss: 1.2672 - val_sparse_categorical_crossentropy: 3.0225 - val_masked_loss: 3.2646 - val_sparse_categorical_accuracy: 0.4562
# Epoch 57/200
# 58/58 [==============================] - 14s 246ms/step - loss: 0.3497 - sparse_categorical_crossentropy: 0.8463 - masked_loss: 0.9144 - sparse_categorical_accuracy: 0.7477 - val_loss: 1.3163 - val_sparse_categorical_crossentropy: 3.1395 - val_masked_loss: 3.3910 - val_sparse_categorical_accuracy: 0.4553
# Epoch 58/200
# 58/58 [==============================] - 17s 305ms/step - loss: 0.3486 - sparse_categorical_crossentropy: 0.8307 - masked_loss: 0.8974 - sparse_categorical_accuracy: 0.7500 - val_loss: 1.3082 - val_sparse_categorical_crossentropy: 3.1202 - val_masked_loss: 3.3702 - val_sparse_categorical_accuracy: 0.4632
# Epoch 59/200
# 58/58 [==============================] - 10s 173ms/step - loss: 0.3420 - sparse_categorical_crossentropy: 0.8082 - masked_loss: 0.8731 - sparse_categorical_accuracy: 0.7588 - val_loss: 1.3775 - val_sparse_categorical_crossentropy: 3.2855 - val_masked_loss: 3.5487 - val_sparse_categorical_accuracy: 0.4610
# Epoch 60/200
# 58/58 [==============================] - 7s 118ms/step - loss: 0.3343 - sparse_categorical_crossentropy: 0.7874 - masked_loss: 0.8508 - sparse_categorical_accuracy: 0.7629 - val_loss: 1.3268 - val_sparse_categorical_crossentropy: 3.1646 - val_masked_loss: 3.4181 - val_sparse_categorical_accuracy: 0.4580
# Epoch 61/200
# 58/58 [==============================] - 7s 121ms/step - loss: 0.3162 - sparse_categorical_crossentropy: 0.7612 - masked_loss: 0.8223 - sparse_categorical_accuracy: 0.7696 - val_loss: 1.3356 - val_sparse_categorical_crossentropy: 3.1855 - val_masked_loss: 3.4406 - val_sparse_categorical_accuracy: 0.4688
# Epoch 144/200
# 58/58 [==============================] - 7s 121ms/step - loss: 0.0534 - sparse_categorical_crossentropy: 0.1297 - masked_loss: 0.1402 - sparse_categorical_accuracy: 0.9577 - val_loss: 2.1382 - val_sparse_categorical_crossentropy: 5.0997 - val_masked_loss: 5.5082 - val_sparse_categorical_accuracy: 0.4718
# Epoch 145/200
# 58/58 [==============================] - 6s 110ms/step - loss: 0.0560 - sparse_categorical_crossentropy: 0.1324 - masked_loss: 0.1430 - sparse_categorical_accuracy: 0.9581 - val_loss: 2.0992 - val_sparse_categorical_crossentropy: 5.0067 - val_masked_loss: 5.4077 - val_sparse_categorical_accuracy: 0.4827
# Epoch 146/200
# 58/58 [==============================] - 9s 165ms/step - loss: 0.0521 - sparse_categorical_crossentropy: 0.1251 - masked_loss: 0.1352 - sparse_categorical_accuracy: 0.9597 - val_loss: 2.1043 - val_sparse_categorical_crossentropy: 5.0188 - val_masked_loss: 5.4208 - val_sparse_categorical_accuracy: 0.4814
# Epoch 147/200
# 58/58 [==============================] - 9s 153ms/step - loss: 0.0555 - sparse_categorical_crossentropy: 0.1300 - masked_loss: 0.1404 - sparse_categorical_accuracy: 0.9575 - val_loss: 2.1098 - val_sparse_categorical_crossentropy: 5.0321 - val_masked_loss: 5.4351 - val_sparse_categorical_accuracy: 0.4809
# Epoch 148/200
# 58/58 [==============================] - 9s 154ms/step - loss: 0.0549 - sparse_categorical_crossentropy: 0.1310 - masked_loss: 0.1415 - sparse_categorical_accuracy: 0.9577 - val_loss: 2.1799 - val_sparse_categorical_crossentropy: 5.1993 - val_masked_loss: 5.6156 - val_sparse_categorical_accuracy: 0.4724
# Epoch 149/200
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0518 - sparse_categorical_crossentropy: 0.1227 - masked_loss: 0.1326 - sparse_categorical_accuracy: 0.9600 - val_loss: 2.1170 - val_sparse_categorical_crossentropy: 5.0492 - val_masked_loss: 5.4535 - val_sparse_categorical_accuracy: 0.4802
# Epoch 150/200
# 58/58 [==============================] - 7s 121ms/step - loss: 0.0506 - sparse_categorical_crossentropy: 0.1226 - masked_loss: 0.1325 - sparse_categorical_accuracy: 0.9603 - val_loss: 2.1113 - val_sparse_categorical_crossentropy: 5.0357 - val_masked_loss: 5.4390 - val_sparse_categorical_accuracy: 0.4837
# Epoch 151/200
# 58/58 [==============================] - 6s 109ms/step - loss: 0.0481 - sparse_categorical_crossentropy: 0.1124 - masked_loss: 0.1214 - sparse_categorical_accuracy: 0.9644 - val_loss: 2.1442 - val_sparse_categorical_crossentropy: 5.1141 - val_masked_loss: 5.5237 - val_sparse_categorical_accuracy: 0.4778
# Epoch 152/200
# 58/58 [==============================] - 9s 164ms/step - loss: 0.0508 - sparse_categorical_crossentropy: 0.1222 - masked_loss: 0.1320 - sparse_categorical_accuracy: 0.9606 - val_loss: 2.1112 - val_sparse_categorical_crossentropy: 5.0354 - val_masked_loss: 5.4387 - val_sparse_categorical_accuracy: 0.4802
# Epoch 153/200
# 58/58 [==============================] - 11s 183ms/step - loss: 0.0391 - sparse_categorical_crossentropy: 0.0939 - masked_loss: 0.1014 - sparse_categorical_accuracy: 0.9702 - val_loss: 2.2421 - val_sparse_categorical_crossentropy: 5.3475 - val_masked_loss: 5.7758 - val_sparse_categorical_accuracy: 0.4807
# Epoch 181/200
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0372 - sparse_categorical_crossentropy: 0.0878 - masked_loss: 0.0949 - sparse_categorical_accuracy: 0.9709 - val_loss: 2.2638 - val_sparse_categorical_crossentropy: 5.3992 - val_masked_loss: 5.8316 - val_sparse_categorical_accuracy: 0.4782
# Epoch 182/200
# 58/58 [==============================] - 7s 125ms/step - loss: 0.0353 - sparse_categorical_crossentropy: 0.0860 - masked_loss: 0.0929 - sparse_categorical_accuracy: 0.9719 - val_loss: 2.2390 - val_sparse_categorical_crossentropy: 5.3401 - val_masked_loss: 5.7677 - val_sparse_categorical_accuracy: 0.4828
# Epoch 183/200
# 58/58 [==============================] - 9s 157ms/step - loss: 0.0383 - sparse_categorical_crossentropy: 0.0897 - masked_loss: 0.0969 - sparse_categorical_accuracy: 0.9716 - val_loss: 2.2245 - val_sparse_categorical_crossentropy: 5.3057 - val_masked_loss: 5.7307 - val_sparse_categorical_accuracy: 0.4810
# Epoch 184/200
# 58/58 [==============================] - 10s 171ms/step - loss: 0.0368 - sparse_categorical_crossentropy: 0.0873 - masked_loss: 0.0943 - sparse_categorical_accuracy: 0.9723 - val_loss: 2.2640 - val_sparse_categorical_crossentropy: 5.3998 - val_masked_loss: 5.8322 - val_sparse_categorical_accuracy: 0.4816
# Epoch 185/200
# 58/58 [==============================] - 10s 167ms/step - loss: 0.0344 - sparse_categorical_crossentropy: 0.0813 - masked_loss: 0.0878 - sparse_categorical_accuracy: 0.9735 - val_loss: 2.2457 - val_sparse_categorical_crossentropy: 5.3563 - val_masked_loss: 5.7853 - val_sparse_categorical_accuracy: 0.4821
# Epoch 186/200
# 58/58 [==============================] - 7s 124ms/step - loss: 0.0359 - sparse_categorical_crossentropy: 0.0864 - masked_loss: 0.0934 - sparse_categorical_accuracy: 0.9724 - val_loss: 2.2675 - val_sparse_categorical_crossentropy: 5.4083 - val_masked_loss: 5.8412 - val_sparse_categorical_accuracy: 0.4770
# Epoch 187/200
# 58/58 [==============================] - 9s 157ms/step - loss: 0.0351 - sparse_categorical_crossentropy: 0.0824 - masked_loss: 0.0890 - sparse_categorical_accuracy: 0.9738 - val_loss: 2.2430 - val_sparse_categorical_crossentropy: 5.3498 - val_masked_loss: 5.7782 - val_sparse_categorical_accuracy: 0.4843
# Epoch 188/200
# 58/58 [==============================] - 10s 171ms/step - loss: 0.0347 - sparse_categorical_crossentropy: 0.0823 - masked_loss: 0.0889 - sparse_categorical_accuracy: 0.9739 - val_loss: 2.2452 - val_sparse_categorical_crossentropy: 5.3550 - val_masked_loss: 5.7839 - val_sparse_categorical_accuracy: 0.4810
# Epoch 189/200
# 58/58 [==============================] - 9s 157ms/step - loss: 0.0348 - sparse_categorical_crossentropy: 0.0831 - masked_loss: 0.0898 - sparse_categorical_accuracy: 0.9736 - val_loss: 2.2676 - val_sparse_categorical_crossentropy: 5.4084 - val_masked_loss: 5.8415 - val_sparse_categorical_accuracy: 0.4817
# Epoch 199/200
# 58/58 [==============================] - 6s 112ms/step - loss: 0.0316 - sparse_categorical_crossentropy: 0.0755 - masked_loss: 0.0815 - sparse_categorical_accuracy: 0.9749 - val_loss: 2.3267 - val_sparse_categorical_crossentropy: 5.5494 - val_masked_loss: 5.9937 - val_sparse_categorical_accuracy: 0.4794
# Epoch 200/200
# 58/58 [==============================] - 10s 173ms/step - loss: 0.0331 - sparse_categorical_crossentropy: 0.0802 - masked_loss: 0.0866 - sparse_categorical_accuracy: 0.9746 - val_loss: 2.3094 - val_sparse_categorical_crossentropy: 5.5082 - val_masked_loss: 5.9493 - val_sparse_categorical_accuracy: 0.4817

# %%
# Возьмем первые 10 значений данных
for i in range(10):
  translation = [tokenizer_en.vocab_size]

  # Пройдём по каждому токену (максимум 30) и сделаем предикт
  for _ in range(30):
    predict = model.predict([questions_batch[i:i+1],np.asarray([translation])]) # Делаем предикт
    translation.append(np.argmax(predict[-1,-1]))        # Ищем индекс токена
    if translation[-1] == tokenizer_en.vocab_size + 1:  # Если предсказан выходной тег, то заканчиваем цикл
      break

  # Запишем реальный ответ
  real_translation = []
  for w in answers_batch[:,1:][i].numpy():
    if w == tokenizer_en.vocab_size + 1:
      break
    real_translation.append(w)

  # Запишем вопрос
  real_text = []
  for w in questions_batch[:,1:][i].numpy():
    if w == tokenizer_en.vocab_size + 1:
      break
    real_text.append(w)

  print('Вопрос:             ', tokenizer_en.decode(real_text))
  print('Реальный ответ:     ', tokenizer_en.decode(real_translation))
  print('Ответ трансформера: ', tokenizer_en.decode(translation[1:-1]))
  print("")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# Вопрос:              what year did the seahawks win the superbowl?
# Реальный ответ:      2006 NFL season
# Ответ трансформера:  1965 NBA FPL season
#
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# Вопрос:              who inspired obama?
# Реальный ответ:      Saul Alinsky
# Ответ трансформера:  Writer
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# Вопрос:              who killed martin luther king jr video?
# Реальный ответ:      Assassination by firearm
# Ответ трансформера:  Cryland
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# Вопрос:              where did charles darwin and his wife live?
# Реальный ответ:      Downe, Kent
# Ответ трансформера:  Empton Oules
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# Вопрос:              what happened at benghazi?
# Реальный ответ:      2012 U.S. diplomatic missions attacks
# Ответ трансформера:  Georgia Bulldogs football
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 57ms/step
# Вопрос:              what was dr seuss education?
# Реальный ответ:      Dartmouth College
# Ответ трансформера:  Caldicott of Chavist
#
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# Вопрос:              where does sherrod brown live?
# Реальный ответ:      Mansfield
# Ответ трансформера:  Hudson Cawel
#
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# Вопрос:              what was jesse owens education?
# Реальный ответ:      Ohio State University
# Ответ трансформера:  Jackson County, sengler
#
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# Вопрос:              where does the shannon river start and end?
# Реальный ответ:      Shannon Pot
# Ответ трансформера:  Shannon Estuary
#
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Вопрос:              who plays king julian madagascar?
# Реальный ответ:      Sacha Baron Cohen
# Ответ трансформера:  Tônza Rangolie
